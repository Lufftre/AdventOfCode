#.#####.#.###.#.#.#.#.###.###.#.#.#.#####.#.#.#.#.#.#####.#.#.#####.#####.#####.#####.#.#.#######.#.#.#####.#####.#.###.#.#####.#####.#.#.###
#.#...#.#...#.#.....#...................................#...#...#...#.........#...#.#...#.#.....#...#.#.........#.#.#.#.#.....#.#...#...#...#
#.#.#.#.###.#####.#.###.###.#.#.#.###.#.###.#.#.###.#.#########.#####.#######.#.#.#.#######.###.#.#.#.#.###.###.###.#.#.#####.###.#.#.#.###.#
#S..#.....#.............#.......#.....#.....#.......#.................#.........#...........#.....#.#.........#.......#...........#...#.....#
#############################################################################################################################################""".splitlines()

# %%
def find_start(map):
    start = None
    end = None
    for y, row in enumerate(map):
        for x, c in enumerate(row):
            if c == "S":
                start = (x, y)
                if end is not None:
                    return start, end
            if c == "E":
                end = (x, y)
                if start is not None:
                    return start, end

def get_neighbours(map, pos, current_dir, seen):
    ns = []
    for dx, dy in [(1, 0), (-1, 0), (0, 1), (0, -1)]:
        if (current_dir[0]*-1, current_dir[1]*-1) == (dx, dy):
            continue

        xx = pos[0] + dx
        yy = pos[1] + dy
        if (xx, yy) in seen:
            continue
        if current_dir == (dx, dy):
            s = 1
        else:
            s = 1001

        if map[yy][xx] != "#":
            ns.append((s, (xx, yy), (dx, dy)))
    return ns

def heuristic(pos, endpos):
    x, y = pos
    xx, yy = endpos
    e = 1000 if x != xx and y != yy else 0
    return abs(x-xx) + abs(y-yy) + e

def bfs(map, startpos, endpos):
    frontier = [(0, 0, startpos, (1, 0), [], [])]
    while True:
        frontier.sort()
        h, score, pos, dir, seen, path = frontier.pop(0)
        path.append((pos, score, dir))
        if map[pos[1]][pos[0]] == "E":
            return score, seen, path
        seen.append(pos)
        ns = get_neighbours(map, pos, dir, seen)
        for s, new_pos, new_dir in ns:
            frontier.append((s+score+heuristic(new_pos, endpos), s+score, new_pos, new_dir, seen, path.copy()))

startpos, endpos = find_start(test)
s, seen, goldenpath = bfs(test, startpos, endpos)
goldenpath_path = [p[0] for p in goldenpath]
golden_posscore = [(p[0], p[1]) for p in goldenpath]
golden_map = {pos: score for pos, score, dir in goldenpath}

print(s)
# Out:
# 11048

# %%
def find_start(map):
    start = None
    end = None
    for y, row in enumerate(map):
        for x, c in enumerate(row):
            if c == "S":
                start = (x, y)
                if end is not None:
                    return start, end
            if c == "E":
                end = (x, y)
                if start is not None:
                    return start, end

def get_neighbours(map, pos, current_dir, seen):
    ns = []
    for dx, dy in [(1, 0), (-1, 0), (0, 1), (0, -1)]:
        if (current_dir[0]*-1, current_dir[1]*-1) == (dx, dy):
            continue

        xx = pos[0] + dx
        yy = pos[1] + dy
        if (xx, yy) in seen:
            continue
        if current_dir == (dx, dy):
            s = 1
        else:
            s = 1001

        if map[yy][xx] != "#":
            ns.append((s, (xx, yy), (dx, dy)))
    return ns

def heuristic(pos, endpos):
    x, y = pos
    xx, yy = endpos
    e = 1000 if x != xx and y != yy else 0
    return abs(x-xx) + abs(y-yy) + e

def bfs(map, startpos, endpos):
    frontier = [(0, startpos, (1, 0), [], [])]
    paths = []
    while len(frontier) > 0:
        print(len(frontier))
        score, pos, dir, seen, path = frontier.pop(0)
        if len(frontier) > 1 and pos in golden_map:
            if score == golden_map[pos]:
                paths.append(path)
            continue
        path.append((pos, score))
        if map[pos[1]][pos[0]] == "E":
            paths.append(path)
            continue
        seen.append(pos)
        ns = get_neighbours(map, pos, dir, seen)
        for s, new_pos, new_dir in ns:
            # if s + score > 90460:
            # if s + score > 11048:
            if s + score > 90460:
                continue
            frontier.append((s+score, new_pos, new_dir, seen, path.copy()))
    return paths
startpos, endpos = find_start(test)
ps = bfs(test, startpos, endpos)
s = set()
print(ps)
for p in ps:
    for ((x,y), score) in p:
        s.add((x,y))
print(len(s))

# %%
def find_start(map):
    start = None
    end = None
    for y, row in enumerate(map):
        for x, c in enumerate(row):
            if c == "S":
                start = (x, y)
                if end is not None:
                    return start, end
            if c == "E":
                end = (x, y)
                if start is not None:
                    return start, end

def get_neighbours(map, pos, current_dir, seen):
    ns = []
    for dx, dy in [(1, 0), (-1, 0), (0, 1), (0, -1)]:
        if (current_dir[0]*-1, current_dir[1]*-1) == (dx, dy):
            continue

        xx = pos[0] + dx
        yy = pos[1] + dy
        if (xx, yy) in seen:
            continue
        if current_dir == (dx, dy):
            s = 1
        else:
            s = 1001

        if map[yy][xx] != "#":
            ns.append((s, (xx, yy), (dx, dy)))
    return ns

def heuristic(pos, endpos):
    x, y = pos
    xx, yy = endpos
    e = 1000 if x != xx and y != yy else 0
    return abs(x-xx) + abs(y-yy) + e

def bfs(map, startpos, endpos):
    frontier = [(0, 0, startpos, (1, 0), [], [])]
    while True:
        frontier.sort()
        h, score, pos, dir, seen, path = frontier.pop(0)
        path.append((pos, score, dir))
        if map[pos[1]][pos[0]] == "E":
            return score, seen, path
        seen.append(pos)
        ns = get_neighbours(map, pos, dir, seen)
        for s, new_pos, new_dir in ns:
            frontier.append((s+score+heuristic(new_pos, endpos), s+score, new_pos, new_dir, seen, path.copy()))

paths = set()
startpos, endpos = find_start(test)

s, seen, goldenpath = bfs(test, startpos, endpos)
goldenpath_path = [p[0] for p in goldenpath]
for pos in goldenpath_path:
    paths.add(pos)
print(paths)
print(len(paths))
# Out:
# {(12, 7), (3, 7), (14, 7), (3, 10), (5, 13), (4, 15), (3, 13), (8, 9), (10, 9), (1, 6), (11, 8), (2, 5), (1, 9), (15, 2), (1, 12), (15, 5), (1, 15), (6, 11), (7, 10), (3, 9), (3, 6), (3, 12), (3, 15), (5, 12), (5, 15), (11, 7), (1, 5), (1, 11), (13, 7), (15, 4), (1, 8), (1, 14), (15, 7), (15, 1), (7, 9), (3, 5), (3, 11), (3, 8), (3, 14), (5, 11), (9, 9), (5, 14), (11, 9), (1, 7), (1, 13), (15, 6), (1, 10), (15, 3), (7, 11)}
# 49

# %%
for y, row in enumerate(test):
    for x, c in enumerate(row):
        if (x, y) in s:
                print("O", end="")
        else:
            print(c, end="")
    print()
# Out:
# ###############
# #.......#OOOOO#
# #.#.###.#O###O#
# #.....#.#OOO#O#
# #.###.#####O#O#
# #.#.#....OOO#O#
# #.#.#####O###O#
# #....OOOOOOO#O#
# ###.#O#####O#O#
# #...#O....#O#O#
# #.#.#O###.#O#O#
# #OOOOO#...#O#O#
# #O###.#.#.#O#O#
# #O..#.....#OOO#
# ###############
